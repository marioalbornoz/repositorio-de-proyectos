# %%
import pandas as pd

# %%
mi_horario = pd.DataFrame(
{
    "Hora"  : ["08:00 - 09:30","09:40 - 11:20", "11:30 - 12:50", "13:00 - 14:30", "14:40 - 16:10", "16:20 - 17:50", "18:00 - 19:30","19:40 - 21:00"],
    "Lunes" : ["", "", "Sistemas de informacion","Sistemas de informacion", "", "", "ITIL", "ITIL"],
    "Martes": ["", "Comunicacion de datos", "Comunicacion de datos","", "Inferencia estadistica", "Evalucacion de proyectos","",""],
    "Miercoles": ["","","","","Comunicacion de datos","","",""],
    "Jueves": ["","","","Sistemas de informacion","Inferencia estadistica", "Evaluacion de proyectos","",""],
    "Viernes":["","","","","","","",""]
})
mi_horario
# Out:
#             Hora                   Jueves                    Lunes  \
# 0  08:00 - 09:30
# 1  09:40 - 11:20
# 2  11:30 - 12:50                           Sistemas de informacion
# 3  13:00 - 14:30  Sistemas de informacion  Sistemas de informacion
# 4  14:40 - 16:10   Inferencia estadistica
# 5  16:20 - 17:50  Evaluacion de proyectos
# 6  18:00 - 19:30                                              ITIL
# 7  19:40 - 21:00                                              ITIL
#
#                      Martes              Miercoles Viernes
# 0
# 1     Comunicacion de datos
# 2     Comunicacion de datos
# 3
# 4    Inferencia estadistica  Comunicacion de datos
# 5  Evalucacion de proyectos
# 6
# 7

# %%
mi_horario.to_excel('Horario.xls')
