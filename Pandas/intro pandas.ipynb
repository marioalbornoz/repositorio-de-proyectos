# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.24.1'

# %%
rick_and_morty = pd.DataFrame(
    {
        "Nombre" : ["Rick", "Morty"],
        "Apellido" : ["Sanchez", "Smith"],
        "Edad" : [60,14]
    }
)
rick_and_morty
# Out:
#   Nombre Apellido  Edad
# 0   Rick  Sanchez    60
# 1  Morty    Smith    14

# %%
rick_and_morty = pd.DataFrame(
[
    ["Rick", "Sanchez", 60],
    ["Morty", "Smith", 14]
], columns= ["Nombre","Aplellido","Edad"]
)
rick_and_morty
# Out:
#   Nombre Aplellido  Edad
# 0   Rick   Sanchez    60
# 1  Morty     Smith    14

# %%
# !head -n 5 ../curso_data_science/Secciones/Seccion3.Intro_a_Data_Science/Intro_a_Pandas/primary_results.csv
# Out:
# state,state_abbreviation,county,fips,party,candidate,votes,fraction_votes
# Alabama,AL,Autauga,1001.0,Democrat,Bernie Sanders,544,0.182
# Alabama,AL,Autauga,1001.0,Democrat,Hillary Clinton,2387,0.8
# Alabama,AL,Baldwin,1003.0,Democrat,Bernie Sanders,2694,0.32899999999999996
# Alabama,AL,Baldwin,1003.0,Democrat,Hillary Clinton,5290,0.647

# %%
votos=pd.read_csv("../curso_data_science/Secciones/Seccion3.Intro_a_Data_Science/Intro_a_Pandas/primary_results.csv")

# %%
votos
# Out:
#          state state_abbreviation                county        fips  \
# 0      Alabama                 AL               Autauga      1001.0
# 1      Alabama                 AL               Autauga      1001.0
# 2      Alabama                 AL               Baldwin      1003.0
# 3      Alabama                 AL               Baldwin      1003.0
# 4      Alabama                 AL               Barbour      1005.0
# 5      Alabama                 AL               Barbour      1005.0
# 6      Alabama                 AL                  Bibb      1007.0
# 7      Alabama                 AL                  Bibb      1007.0
# 8      Alabama                 AL                Blount      1009.0
# 9      Alabama                 AL                Blount      1009.0
# 10     Alabama                 AL               Bullock      1011.0
# 11     Alabama                 AL               Bullock      1011.0
# 12     Alabama                 AL                Butler      1013.0
# ...

# %%
df = votos

# %%
df.to_csv('example.csv')

# %%
# !head -n 5 example.csv
# Out:
# ,state,state_abbreviation,county,fips,party,candidate,votes,fraction_votes
# 0,Alabama,AL,Autauga,1001.0,Democrat,Bernie Sanders,544,0.182
# 1,Alabama,AL,Autauga,1001.0,Democrat,Hillary Clinton,2387,0.8
# 2,Alabama,AL,Baldwin,1003.0,Democrat,Bernie Sanders,2694,0.329
# 3,Alabama,AL,Baldwin,1003.0,Democrat,Hillary Clinton,5290,0.647

# %%
df = pd.read_csv('example.csv')

# %%
df
# Out:
#        Unnamed: 0    state state_abbreviation                county  \
# 0               0  Alabama                 AL               Autauga
# 1               1  Alabama                 AL               Autauga
# 2               2  Alabama                 AL               Baldwin
# 3               3  Alabama                 AL               Baldwin
# 4               4  Alabama                 AL               Barbour
# 5               5  Alabama                 AL               Barbour
# 6               6  Alabama                 AL                  Bibb
# 7               7  Alabama                 AL                  Bibb
# 8               8  Alabama                 AL                Blount
# 9               9  Alabama                 AL                Blount
# 10             10  Alabama                 AL               Bullock
# 11             11  Alabama                 AL               Bullock
# 12             12  Alabama                 AL                Butler
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0          fips          votes  fraction_votes
# count  24611.000000  2.451100e+04   24611.000000    24611.000000
# mean   12305.000000  2.667152e+07    2306.252773        0.304524
# std     7104.728074  4.200978e+07    9861.183572        0.231401
# min        0.000000  1.001000e+03       0.000000        0.000000
# 25%     6152.500000  2.109100e+04      68.000000        0.094000
# 50%    12305.000000  4.208100e+04     358.000000        0.273000
# 75%    18457.500000  9.090012e+07    1375.000000        0.479000
# max    24610.000000  9.560004e+07  590502.000000        1.000000
