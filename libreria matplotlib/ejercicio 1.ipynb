# %%
from pylab import *      # importar todas las funciones de pylab

# %%
x = arange(10.)          # array de floats, de 0.0 a 9.0

# %%
plot(x)                  # generar el gráfico de la función y=x

# %%
show()                   # mostrar el gráfico en pantalla

# %%
ion()             # Activo el modo interactivo

# %%
plot(x)           # Hago un plot que se muestra sin hacer show()

# %%
mi_dibujo, = plot(x)

# %%
plot(x,'o')  # pinta 10 puntos como o

# %%
plot(x,'o-')

# %%
mi_dibujo, = plot(x*2,'bx-')

# %%
clf()   # Limpiamos toda la figura

# %%
x2=x**2   # definimos el array x2

# %%
x3=x**3    # definimos el array x3

# %% [markdown]
# # dibujamos tres curvas en el mismo gráfico y figura

# %%
plot(x, x,'b.', x, x2,'rd', x, x3,'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x7f08d5b00358>,
#  <matplotlib.lines.Line2D at 0x7f08d5b00470>,
#  <matplotlib.lines.Line2D at 0x7f08d5b007f0>]

# %%
xlim(-1,11)     # nuevos límites para el eje OX
# Out:
# (-1, 11)

# %%
ylim(-50,850)   # nuevos límites para el eje OY
# Out:
# (-50, 850)

# %%
plot(x, lw=5, c='y', marker='o', ms=10, mfc='red')

# %%
x = arange(0, 5, 0.05)

# %%
p, = plot(x,log10(x)*sin(x**2))
# Out:
# /home/malbornoz/anaconda3/envs/proyectos/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# /home/malbornoz/anaconda3/envs/proyectos/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in multiply
#   """Entry point for launching an IPython kernel.

# %%
xlabel('Eje X')        # Etiqueta del eje OX
# Out:
# Text(0.5, 0, 'Eje X')

# %%
ylabel('Eje Y')        # Etiqueta del eje OY
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
title('Mi grafica')    # Título del gráfico
# Out:
# Text(0.5, 1.0, 'Mi grafica')

# %%
text(1, -0.4, 'Nota')  # Texto en coodenadas (1, -0.4)
# Out:
# Text(1, -0.4, 'Nota')

# %%
from math import *
from numpy import *

t = arange(0.1, 20, 0.1)

y1 = sin(t)/t
y2 = sin(t)*exp(-t)
p1, p2 = plot(t, y1, t, y2)

# Texto en la gráfica en coordenadas (x,y)
texto1 = text(2, 0.6, r'$\frac{\sin(x)}{x}$', fontsize=20)
texto2 = text(13, 0.2, r'$\sin(x) \cdot e^{-x}$', fontsize=16)

# Añado una malla al gráfico
grid()

title('Representacion de dos funciones')
xlabel('Tiempo / s')
ylabel('Amplitud / cm')

show()

# %% [markdown]
# Colores
# Símbolo 	Color
# “b” 	Azul
# “g” 	Verde
# “r” 	Rojo
# “c” 	Cian
# “m” 	Magenta
# “y” 	Amarillo
# “k” 	Negro
# “w” 	Blanco
#
# Marcas y líneas
# Símbolo 	Descripción
# “-“ 	Línea continua
# “–” 	Línea a trazos
# “-.” 	Línea a puntos y rayas
# “:” 	Línea punteada
# “.” 	Símbolo punto
# “,” 	Símbolo pixel
# “o” 	Símbolo círculo relleno
# “v” 	Símbolo triángulo hacia abajo
# “^” 	Símbolo triángulo hacia arriba
# “<” 	Símbolo triángulo hacia la izquierda
# “>” 	Símbolo triángulo hacia la derecha
# “s” 	Símbolo cuadrado
# “p” 	Símbolo pentágono
# “*” 	Símbolo estrella
# “+” 	Símbolo cruz
# “x” 	Símbolo X
# “D” 	Símbolo diamante
# “d” 	Símbolo diamante delgado
